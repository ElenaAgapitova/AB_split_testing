# %% [markdown]
# ## Практическое задание №1
#
# **1. Выберите любой продукт.** Например ваш продукт:
#     ozon.ru,
#     citilink.ru,
#     telegram
#
#    *Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить*
#
#
# **2. Сформулируйте 5-10 гипотез для выбранного продукта.**

# %% [markdown]
# ### Задание 1.
# **Расмотрим ozon.ru.**
# Я бы выделила следующие ключевые метрики:
# * CR - доля пользователей, которые сделали заказ
# * ARPU - доход, который приносит пользователь за определенный период времени
# * ARPPU - средний доход от одного платящего
# * LTV - среднее количество денег от одного пользователя за весь период
# * Retention - показатель удержания пользователей
# * Paying Share - доля платящих из всей аудитории
# * MAU - число уникальных пользователей в месяц
# * Показатель отказов
# * Периодичность визитов
# * Среднее время сеанса
#
# По данных метрикам мы можем сегментировать наших пользователей и провести анализ, почему пользователь не совершил заказ, какой доход приносит нам пользователь, выделить постоянных клиентов, стимулировать к заказу пользователей, которые давно не совершали заказ, в каком месте пользователь испытывает трудности и в итоге отказывается от заказа. Работают ли рекламные акции и предложения - увеличивается ли количество новых пользователей. Проанализировав данные метрики, мы можем сформулировать гипотезы, которые позволят нам провести тест и внести изменения для улучшения показателей.
# Например, наблюдается, что пользователь имеет высокие показатели периодичности визитов на сайте и время сеанса, но не совершает заказ, необходимо выяснить, почему он упорно ищет, но не заказывает, возможно есть какая-то трудность в оформлении заказа или описание товара недостаточно информативно, что вызывает сомнение, либо он желает приобрести товар по более выгодной цене, поэтому регулярно мониторит цены. Мы можем ему рекомендовать этот же продукт по ценам от других дистрибьюторов, или предложить подписаться на уведомления о скидках на товар. Данная услуга уже есть у ozon, также уведомление, что через какой-то период времени будет действовать скидка на товар, что естесвенно повышает лояльность пользователей и конверсию в заказ.
#
#
# **Расмотрим citilink. Citilink является интернет-магазином по продаже техники и электроники, таким образом метрики с ozon в целом совпадают.**
#
# **Расмотрим telegram (как социальную сеть в целом)**
# * DAU - число уникальных пользователей в день
# * MAU - число уникальных пользователей в месяц
# * Периодичность визитов
# * Среднее время сеанса
# * Retention - показатель удержания пользователей
# * CR - доля пользователей, которые оформили подписку премиум
# * Paying Share - доля платящих из всей аудитории
# * ARPU - доход, который приносит пользователь за определенный период времени
# * ARPPU - средний доход от одного платящего
#
# Для владельцов телеграм-каналов будут ключевыми такие метрики:
# * Количество подписчиков и их прирост за неделю
# * Рост подписчиков за определенный период
# * Включение/выключение уведомлений
# * Просмотры по часам
# * Вовлеченность/активность пользователей (лайки, репосты)
# * Источники прихода
# * Охваты публикаций
# * ИЦ (индекс цитирования)- сообщает о том, как часто канал появляется в рекламе
# Если же в канале предлагаются какие-либо услуги или товары, то также будет необходимо:
# * Конверсия в заказ/покупку
#
# Ранее до запрета пользовался спросом инстаграм, в настоящее время предполагаю, что телеграм значительно увеличил, как число уникальных пользователей, так периодичность визитов, время сеанса, многие пользователи начали им пользоваться более активно вновь спустя какое-то время. Также появились новые каналы или стали развиваться более активно существующие по продаже услуг или товаров. По положительной практике инстаграм появились сторисы, но по подписке премиум)

# %% [markdown]
# ### Задание №2
#
# **OZON**
# Для формулирования гипотез конечно не хватает метрик, ибо некоторые неудобные моменты есть скорее всего непросто так, но будем считать, что это просто примеры:)
#
# 1. Если увеличит лимит озон-карты с 15 000 до 30 000 (не знаю возможно ли это) для активных постоянных пользователей, совершающих заказы сумма, которых превышает лимит, то мы увеличим конверсию в заказ на 1-2% и уменьшим показатель отказа на 1-2%, потому что упростим оформление заказа для пользователя и повысим его лояльность.
#
# Безусловно здесь необходимо смотреть на метрики, насколько это необходимо, какое количество пользователей превышает лимит, но ранее столкнулась с такой проблемой, так как не смогла пополнить карту более этого лимита и приобрести товар, чтобы понять в чем дело, потратила время, ну и огорчило отсутствие такой возможности. Предполагаю, что лимит такой неслучайно, да и товары приобретаются на сумму свыше 15 000 скорее всего редко, по стечению обстоятельств у пользователя, и если пользователю очень надо, то оплатит и так, но все же это влияет на сервис. Если нет возможности изменить лимит => гипотеза №2
#
# 2. Если информировать пользователя при оформление заказа, что он привысил лимит и не может оплатить товар озон-картой (для пользователей, которые превышают лимиты), предложить ему промокод со скидкой 3-5% на следующий заказ, то мы увеличим конверсию в заказ на 1-2%, потому что повысим лояльность пользователей и стимулируем его на оформление следующего заказа.
#
# **CITILINK**
# 1. Если переместить фильтры по подбору техники по параметрам в левую часть экрана и разместить в начале для всех пользователей, то мы увеличим конверсию в заказ на 1-2%, потому что пользователю будет удобнее, привычнее и проще подобрать необходимую модель из огромного количества предложенных.
#
# Так например,  при выборе холодильника предлагается 800 товаров, выбрать из такого количества нереально, поэтому необходимо отфильтровать ассортимент, но фильтры изначально не видны, обнаруживаются при скроллинге страницы и справа, что мне показалось неудобно, так как это все затрудняет подбор необходимой модели.
#
# 2. Если основную информацию о скидке, как и срок, разместить на картинке для всех пользователей, то мы уменьшим показатель отказа на 1%, потому что пользователь будет видить конкретное предложение и его срок действия без дополнительного скроллинга.
#
# Если честно, возможно это субъективно, но мне сайт не очень понравился, зайдя в акции, сразу хочется их покинуть, поскольку необходимо просматривать каждое предложение, так как сразу неочевидно подходит ли мне данное акция или нет, учитывая факт, что их весьма много. Лучше, когда их 3-4 и они информативны при первом взгляде, стимулирует не упустить возможность воспользоваться предложением, а проводить анализ всех утомительно:)
#
# **TELEGRAM**
# 1. Если сделать бесплатную пробную версию подписки премиум на один месяц для всех пользователей, то мы увеличим конверсию на 1-2% в подписку, потому что у пользователя будет возможность попробовать возможности подписки, привыкнуть к преимуществам и продолжить ей пользоваться.
#
# 2. Если сделать несколько (станадрт, премиум) тарифов подписки с различным функционалам для всех пользователей, то мы увеличим конверсию в подписку на 1-2%, так у пользователя будет выбор использовать только необходимый функционал.
